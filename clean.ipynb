# %%
import fiscalpy as fp
import pandas as pd
from fiscalpy import limpieza_ingresos_territoriales
from fiscalpy import columnas_ingresos_territoriales

# %%
df = pd.read_excel("C:/Users/SebasM/OneDrive/Documentos/try/ejec_ing_25.xlsx")

# %%
df
# Out:
#         Año Vigencia                    Periodo  Cadena Periodo  Código DANE  \
# 0               2025  Anual (Enero - Diciembre)           11212         5000
# 1               2025  Anual (Enero - Diciembre)           11212         5000
# 2               2025  Anual (Enero - Diciembre)           11212         5000
# 3               2025  Anual (Enero - Diciembre)           11212         5000
# 4               2025  Anual (Enero - Diciembre)           11212         5000
# ...              ...                        ...             ...          ...
# 155420          2025  Anual (Enero - Diciembre)           11212        27493
# 155421          2025  Anual (Enero - Diciembre)           11212        27493
# 155422          2025  Anual (Enero - Diciembre)           11212        27493
# 155423          2025  Anual (Enero - Diciembre)           11212        27493
# 155424          2025  Anual (Enero - Diciembre)           11212        27493
#
# ...

# %%
norm_data = limpieza_ingresos_territoriales(df, tipo='ejecucion')
# Out:
# c:\Users\SebasM\AppData\Local\Programs\Python\Python313\Lib\site-packages\fiscalpy\limpieza.py:222: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'INGRESOS' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df2.loc[idx, f'col_{i}'] = dictio_con['.'.join(split[:i])]
# c:\Users\SebasM\AppData\Local\Programs\Python\Python313\Lib\site-packages\fiscalpy\limpieza.py:222: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'INGRESOS CORRIENTES' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df2.loc[idx, f'col_{i}'] = dictio_con['.'.join(split[:i])]
# ...

# %%
norm_data
# Out:
#        Año Vigencia  Código DANE    Entidad Tipo de Entidad Departamento  \
# 0              2025         5000  Antioquia    Departamento    Antioquia
# 1              2025         5000  Antioquia    Departamento    Antioquia
# 2              2025         5000  Antioquia    Departamento    Antioquia
# 3              2025         5000  Antioquia    Departamento    Antioquia
# 4              2025         5000  Antioquia    Departamento    Antioquia
# ...             ...          ...        ...             ...          ...
# 49317          2025        99773   Cumaribo       Municipio      Vichada
# 49318          2025        99773   Cumaribo       Municipio      Vichada
# 49319          2025        99773   Cumaribo       Municipio      Vichada
# 49320          2025        99773   Cumaribo       Municipio      Vichada
# 49321          2025        99773   Cumaribo       Municipio      Vichada
#
#           col_1                col_2  \
# 0      INGRESOS  INGRESOS CORRIENTES
# ...

# %%
norm_data.to_excel("ejec_clean25.xlsx", index=False)

# %%
df_2 = pd.read_excel("C:/Users/SebasM/OneDrive/Documentos/try/2025_8_CUIPOA_PROGRAMACION_DE_INGRESOS.xlsx")

# %%
norm_data_1 = limpieza_ingresos_territoriales(df_2, tipo='programacion')
# Out:
# c:\Users\SebasM\AppData\Local\Programs\Python\Python313\Lib\site-packages\fiscalpy\limpieza.py:222: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'INGRESOS' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df2.loc[idx, f'col_{i}'] = dictio_con['.'.join(split[:i])]
# c:\Users\SebasM\AppData\Local\Programs\Python\Python313\Lib\site-packages\fiscalpy\limpieza.py:222: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'INGRESOS CORRIENTES' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df2.loc[idx, f'col_{i}'] = dictio_con['.'.join(split[:i])]
# ...

# %%
norm_data_1.to_excel("prog_ing_clean25.xlsx", index=False)

# %%
norm_data_1
# Out:
#        Año Vigencia  Código DANE  \
# 0              2025         5000
# 1              2025         5000
# 2              2025         5000
# 3              2025         5000
# 4              2025         5000
# ...             ...          ...
# 53260          2025        99773
# 53261          2025        99773
# 53262          2025        99773
# 53263          2025        99773
# 53264          2025        99773
#
#                                                  Entidad  \
# 0      Antioquia                                     ...
# 1      Antioquia                                     ...
# 2      Antioquia                                     ...
# 3      Antioquia                                     ...
# 4      Antioquia                                     ...
# ...                                                  ...
# 53260  Cumaribo                                      ...
# 53261  Cumaribo                                      ...
# ...

# %%
norm_data_0 = columnas_ingresos_territoriales(norm_data_1)

# %%
norm_data_0
# Out:
#        Año Vigencia  Código DANE  \
# 0              2025         5000
# 1              2025         5000
# 2              2025         5000
# 3              2025         5000
# 4              2025         5000
# ...             ...          ...
# 53260          2025        99773
# 53261          2025        99773
# 53262          2025        99773
# 53263          2025        99773
# 53264          2025        99773
#
#                                                  Entidad  \
# 0      Antioquia                                     ...
# 1      Antioquia                                     ...
# 2      Antioquia                                     ...
# 3      Antioquia                                     ...
# 4      Antioquia                                     ...
# ...                                                  ...
# 53260  Cumaribo                                      ...
# 53261  Cumaribo                                      ...
# ...

# %%
norm_data_0.to_excel("pro_ing_clean27.xlsx", index=False)

# %%
norm_data_9 = columnas_ingresos_territoriales(norm_data)

# %%
norm_data_9
# Out:
#        Año Vigencia  Código DANE    Entidad Tipo de Entidad Departamento  \
# 0              2025         5000  Antioquia    Departamento    Antioquia
# 1              2025         5000  Antioquia    Departamento    Antioquia
# 2              2025         5000  Antioquia    Departamento    Antioquia
# 3              2025         5000  Antioquia    Departamento    Antioquia
# 4              2025         5000  Antioquia    Departamento    Antioquia
# ...             ...          ...        ...             ...          ...
# 49317          2025        99773   Cumaribo       Municipio      Vichada
# 49318          2025        99773   Cumaribo       Municipio      Vichada
# 49319          2025        99773   Cumaribo       Municipio      Vichada
# 49320          2025        99773   Cumaribo       Municipio      Vichada
# 49321          2025        99773   Cumaribo       Municipio      Vichada
#
#           col_1                col_2  \
# 0      INGRESOS  INGRESOS CORRIENTES
# ...

# %%
norm_data_9.to_excel("eje_ing_clean25.xlsx", index = False)

# %%
norm_data_9["clas_gen2"]
# Out:
# 0           Recursos propios
# 1           Recursos propios
# 2           Recursos propios
# 3           Recursos propios
# 4           Recursos propios
#                 ...
# 49317       Recursos propios
# 49318    Recursos de capital
# 49319    Recursos de capital
# 49320    Recursos de capital
# 49321    Recursos de capital
# Name: clas_gen2, Length: 49322, dtype: object
