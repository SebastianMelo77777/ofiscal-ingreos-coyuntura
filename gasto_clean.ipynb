# %%
import fiscalpy as fp
import pandas as pd
from fiscalpy import limpieza_ingresos_territoriales
from fiscalpy import columnas_ingresos_territoriales
from fiscalpy import limpieza_gastos_territoriales
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import fiscalpy as fp
#       2 import pandas as pd
#       3 from fiscalpy import limpieza_ingresos_territoriales
#
# File c:\Users\SebasM\AppData\Local\Programs\Python\Python313\Lib\site-packages\fiscalpy\__init__.py:1
# ----> 1 from .limpieza import limpieza_gastos_territoriales, limpieza_ingresos_territoriales, columnas_ingresos_territoriales
#       3 __all__ = ["limpieza_gastos_territoriales", "limpieza_ingresos_territoriales", "columnas_ingresos_territoriales"]
#       4 __version__ = "0.0.3"
#
# File c:\Users\SebasM\AppData\Local\Programs\Python\Python313\Lib\site-packages\fiscalpy\limpieza.py:4
#       2 import numpy as np
#       3 import json
# ----> 4 from utils import DIC_ENTS, DIC_SECT
#       6 def columnas_ingresos_territoriales(df):
# ...

# %%
df = pd.read_excel("C:/Users/SebasM/OneDrive/Documentos/try/ejec_gast_25.xlsb")

# %%
df
# Out:
#         Año Vigencia                                            Periodo  \
# 0               2025  Anual (Enero - Diciembre)                     ...
# 1               2025  Anual (Enero - Diciembre)                     ...
# 2               2025  Anual (Enero - Diciembre)                     ...
# 3               2025  Anual (Enero - Diciembre)                     ...
# 4               2025  Anual (Enero - Diciembre)                     ...
# ...              ...                                                ...
# 773410          2025  Anual (Enero - Diciembre)                     ...
# 773411          2025  Anual (Enero - Diciembre)                     ...
# 773412          2025  Anual (Enero - Diciembre)                     ...
# 773413          2025  Anual (Enero - Diciembre)                     ...
# 773414          2025  Anual (Enero - Diciembre)                     ...
#
#         Cadena Periodo  Código DANE  Código FUT  \
# 0                11212         5000   110505000
# ...

# %%
norm_data = limpieza_gastos_territoriales(df, tipo='ejecucion')
# Out:
# c:\Users\SebasM\AppData\Local\Programs\Python\Python313\Lib\site-packages\fiscalpy\limpieza.py:282: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'GASTOS' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df2.loc[idx, f'col_{i}'] = dictio_con['.'.join(split[:i])]
# c:\Users\SebasM\AppData\Local\Programs\Python\Python313\Lib\site-packages\fiscalpy\limpieza.py:282: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'FUNCIONAMIENTO' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df2.loc[idx, f'col_{i}'] = dictio_con['.'.join(split[:i])]
# ...

# %%
norm_data
# Out:
#         Año Vigencia  Código DANE  \
# 0               2025         5000
# 1               2025         5000
# 2               2025         5000
# 3               2025         5000
# 4               2025         5000
# ...              ...          ...
# 171679          2025        99773
# 171680          2025        99773
# 171681          2025        99773
# 171682          2025        99773
# 171683          2025        99773
#
#                                                   Entidad  \
# 0       Antioquia                                     ...
# 1       Antioquia                                     ...
# 2       Antioquia                                     ...
# 3       Antioquia                                     ...
# 4       Antioquia                                     ...
# ...                                                   ...
# 171679  Cumaribo                                      ...
# 171680  Cumaribo                                      ...
# ...

# %%
norm_data.to_excel('eje_gast_clean25.xlsx', index = False)
# Out:
# Exception ignored in: <function ZipFile.__del__ at 0x000001BCD4D44AE0>
# Traceback (most recent call last):
#   File "c:\Users\SebasM\AppData\Local\Programs\Python\Python313\Lib\zipfile\__init__.py", line 1988, in __del__
#     self.close()
#   File "c:\Users\SebasM\AppData\Local\Programs\Python\Python313\Lib\zipfile\__init__.py", line 2005, in close
#     self.fp.seek(self.start_dir)
# ValueError: seek of closed file

# %%
df1 = pd.read_excel("C:/Users/SebasM/OneDrive/Documentos/try/prog_gast_25.xlsb")

# %%
df1
# Out:
#         Año Vigencia                                            Periodo  \
# 0               2025  Anual (Enero - Diciembre)                     ...
# 1               2025  Anual (Enero - Diciembre)                     ...
# 2               2025  Anual (Enero - Diciembre)                     ...
# 3               2025  Anual (Enero - Diciembre)                     ...
# 4               2025  Anual (Enero - Diciembre)                     ...
# ...              ...                                                ...
# 348515          2025  Anual (Enero - Diciembre)                     ...
# 348516          2025  Anual (Enero - Diciembre)                     ...
# 348517          2025  Anual (Enero - Diciembre)                     ...
# 348518          2025  Anual (Enero - Diciembre)                     ...
# 348519          2025  Anual (Enero - Diciembre)                     ...
#
#         Cadena Periodo  Código DANE  Código FUT  \
# 0                11212         5000   110505000
# ...

# %%
norm_data1 = limpieza_gastos_territoriales(df1, tipo='programacion')
# Out:
# c:\Users\SebasM\AppData\Local\Programs\Python\Python313\Lib\site-packages\fiscalpy\limpieza.py:282: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'GASTOS' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df2.loc[idx, f'col_{i}'] = dictio_con['.'.join(split[:i])]
# c:\Users\SebasM\AppData\Local\Programs\Python\Python313\Lib\site-packages\fiscalpy\limpieza.py:282: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'FUNCIONAMIENTO' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df2.loc[idx, f'col_{i}'] = dictio_con['.'.join(split[:i])]
# ...
